# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,7,4]
y=[10,15,25,30]
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x,y,color='green',linestyle='-',marker='o')

# %%
plt.plot(x,y,color='green',linestyle='--',marker='o')

# %%
plt.title('my Plot')
# Out:
# Text(0.5, 1.0, 'my Plot')

# %%
plt.xlabel('x-axis')
# Out:
# Text(0.5, 0, 'x-axis')

# %%
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
x=[1,2,3]
y1=[1,4,9]
y2=[1,2,3]
plt.plot(x,y1,label='squares')
plt.plot(x,y2,label='linear')

# %%
plt.legend()
plt.show()
# Out:
# C:\Users\Mahima S\AppData\Local\Temp\ipykernel_1992\3208844177.py:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
categories=['A','B','C','D']
values=[5,6,0,1]
plt.bar(categories,values)
# Out:
# <BarContainer object of 4 artists>

# %%
data=[1,1,2,3,3,4,4,5]
plt.hist(data,bins=5)
plt.show()

# %%
x=[1,2,3,4]
y=[10,15,25,30]
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.subplot(1,3,1)
# Out:
# <Axes: >

# %%
plt.plot([1,2,3],[1,2,3])

# %%
plt.subplot(1,2,2)
# Out:
# <Axes: >

# %%
plt.plot([1,2,3],[3,2,1])

# %%
plt.show()

# %%
plt.plot(x,y)

# %%
plt.savefig('plot.png')
